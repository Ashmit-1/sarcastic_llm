# %%
import torch
from untrained_model import GPTModel

import os
curr_dir = os.getcwd()
parent_dir = os.path.dirname(curr_dir)
file_path = "dataset/natural_language/large_lang_repo/part00.txt"
final_path = os.path.join(parent_dir, file_path)
print(final_path)

GPT_CONFIG_124M = {
    "vocab_size": 50257,   # Vocabulary size
    "context_length": 256, # Shortened context length (orig: 1024)
    "emb_dim": 256,        # Embedding dimension
    "n_heads": 4,         # Number of attention heads
    "n_layers": 12,        # Number of layers
    "drop_rate": 0.1,      # Dropout rate
    "qkv_bias": False      # Query-key-value bias
}

torch.manual_seed(123)

checkpoint = torch.load(os.path.join(parent_dir, "model_and_optimizer_small.pth"), weights_only=True)

model = GPTModel(GPT_CONFIG_124M)
model.load_state_dict(checkpoint["model_state_dict"])

optimizer = torch.optim.AdamW(model.parameters(), lr=0.0005, weight_decay=0.1)
optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
model.train();
# Out:
# /media/ashmit/External Storage/System/python/llm_from_scratch/llm_from_scratch/dataset/natural_language/large_lang_repo/part00.txt

# %%
import tiktoken
from untrained_model import generate_text_simple


def text_to_token_ids(text, tokenizer):
    encoded = tokenizer.encode(text, allowed_special={'<|endoftext|>'})
    encoded_tensor = torch.tensor(encoded).unsqueeze(0) # add batch dimension
    return encoded_tensor

def token_ids_to_text(token_ids, tokenizer):
    flat = token_ids.squeeze(0) # remove batch dimension
    return tokenizer.decode(flat.tolist())

start_context = "Every effort moves you"
tokenizer = tiktoken.get_encoding("gpt2")

token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids(start_context, tokenizer),
    max_new_tokens=10,
    context_size=GPT_CONFIG_124M["context_length"]
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  Every effort moves you?”
#
# “Oh!�

# %%
with open(final_path, "r", encoding="utf-8") as file:
    text_data = file.read()
print(text_data[:10])
print(text_data[-10:])
# Out:
# One day, a
# next day.

# %%
total_characters = len(text_data)
total_tokens = len(tokenizer.encode(text_data, allowed_special={'<|endoftext|>'}))

print("Characters:", total_characters)
print("Tokens:", total_tokens)
# Out:
# Characters: 3142288
# Tokens: 760140

# %%
from untrained_model import create_dataloader_v1


# Train/validation ratio
train_ratio = 0.90
split_idx = int(train_ratio * len(text_data))
train_data = text_data[:split_idx]
val_data = text_data[split_idx:]


torch.manual_seed(123)

train_loader = create_dataloader_v1(
    train_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=True,
    shuffle=True,
    num_workers=0
)

val_loader = create_dataloader_v1(
    val_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=False,
    shuffle=False,
    num_workers=0
)

# %%
def calc_loss_batch(input_batch, target_batch, model, device):
    input_batch, target_batch = input_batch.to(device), target_batch.to(device)
    logits = model(input_batch)
    loss = torch.nn.functional.cross_entropy(logits.flatten(0, 1), target_batch.flatten())
    return loss


def calc_loss_loader(data_loader, model, device, num_batches=None):
    total_loss = 0.
    if len(data_loader) == 0:
        return float("nan")
    elif num_batches is None:
        num_batches = len(data_loader)
    else:
        # Reduce the number of batches to match the total number of batches in the data loader
        # if num_batches exceeds the number of batches in the data loader
        num_batches = min(num_batches, len(data_loader))
    for i, (input_batch, target_batch) in enumerate(data_loader):
        if i < num_batches:
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            total_loss += loss.item()
        else:
            break
    return total_loss / num_batches

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    
    major, minor = map(int, torch.__version__.split(".")[:2])
    if (major, minor) >= (2, 9):
        device = torch.device("mps")
    else:
        device = torch.device("cpu")
else:
    device = torch.device("cpu")


print(f"Using {device} device.")


model.to(device) 


with torch.no_grad(): 
    train_loss = calc_loss_loader(train_loader, model, device)
    val_loss = calc_loss_loader(val_loader, model, device)

print("Training loss:", train_loss)
print("Validation loss:", val_loss)
# Out:
# Using cpu device.
# Training loss: 8.488191881051895
# Validation loss: 8.050749565337922

# %%
def train_model_simple(model, train_loader, val_loader, optimizer, device, num_epochs,
                       eval_freq, eval_iter, start_context, tokenizer):
    # Initialize lists to track losses and tokens seen
    train_losses, val_losses, track_tokens_seen = [], [], []
    tokens_seen, global_step = 0, -1

    # Main training loop
    for epoch in range(num_epochs):
        model.train()  # Set model to training mode
        
        for input_batch, target_batch in train_loader:
            optimizer.zero_grad() # Reset loss gradients from previous batch iteration
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            loss.backward() # Calculate loss gradients
            optimizer.step() # Update model weights using loss gradients
            tokens_seen += input_batch.numel()
            global_step += 1

            # Optional evaluation step
            if global_step % eval_freq == 0:
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter)
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)
                print(f"Ep {epoch+1} (Step {global_step:06d}): "
                      f"Train loss {train_loss:.3f}, Val loss {val_loss:.3f}")

        # Print a sample text after each epoch
        generate_and_print_sample(
            model, tokenizer, device, start_context
        )

    return train_losses, val_losses, track_tokens_seen


def evaluate_model(model, train_loader, val_loader, device, eval_iter):
    model.eval()
    with torch.no_grad():
        train_loss = calc_loss_loader(train_loader, model, device, num_batches=eval_iter)
        val_loss = calc_loss_loader(val_loader, model, device, num_batches=eval_iter)
    model.train()
    return train_loss, val_loss


def generate_and_print_sample(model, tokenizer, device, start_context):
    model.eval()
    context_size = model.pos_emb.weight.shape[0]
    encoded = text_to_token_ids(start_context, tokenizer).to(device)
    with torch.no_grad():
        token_ids = generate_text_simple(
            model=model, idx=encoded,
            max_new_tokens=50, context_size=context_size
        )
    decoded_text = token_ids_to_text(token_ids, tokenizer)
    print(decoded_text.replace("\n", " "))  # Compact print format
    model.train()

# %%
import time
start_time = time.time()

torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)
model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0004, weight_decay=0.1)

num_epochs = 13
train_losses, val_losses, tokens_seen = train_model_simple(
    model, train_loader, val_loader, optimizer, device,
    num_epochs=num_epochs, eval_freq=5, eval_iter=5,
    start_context="Every effort moves you", tokenizer=tokenizer
)

end_time = time.time()
execution_time_minutes = (end_time - start_time) / 60
print(f"Training completed in {execution_time_minutes:.2f} minutes.")

# checkpoint = torch.load("model_and_optimizer_small.pth", weights_only=True)

# model = GPTModel(GPT_CONFIG_124M)
# model.load_state_dict(checkpoint["model_state_dict"])

# optimizer = torch.optim.AdamW(model.parameters(), lr=0.0005, weight_decay=0.1)
# optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
# model.train();
# Out:
# Ep 1 (Step 000000): Train loss 10.645, Val loss 10.593
# Ep 1 (Step 000005): Train loss 9.648, Val loss 9.618
# Ep 1 (Step 000010): Train loss 9.013, Val loss 9.010
# Ep 1 (Step 000015): Train loss 8.443, Val loss 8.381
# Ep 1 (Step 000020): Train loss 7.720, Val loss 7.766
# Ep 1 (Step 000025): Train loss 7.110, Val loss 7.229
# Ep 1 (Step 000030): Train loss 6.875, Val loss 6.792
# Ep 1 (Step 000035): Train loss 6.450, Val loss 6.495
# Ep 1 (Step 000040): Train loss 6.385, Val loss 6.301
# Ep 1 (Step 000045): Train loss 6.105, Val loss 6.190
# Ep 1 (Step 000050): Train loss 6.214, Val loss 6.114
# Ep 1 (Step 000055): Train loss 6.094, Val loss 6.025
# Ep 1 (Step 000060): Train loss 6.005, Val loss 5.941
# Ep 1 (Step 000065): Train loss 6.009, Val loss 5.870
# Ep 1 (Step 000070): Train loss 5.645, Val loss 5.790
# Ep 1 (Step 000075): Train loss 5.579, Val loss 5.739
# Ep 1 (Step 000080): Train loss 5.751, Val loss 5.683
# Ep 1 (Step 000085): Train loss 5.735, Val loss 5.645
# Ep 1 (Step 000090): Train loss 5.624, Val loss 5.599
# Ep 1 (Step 000095): Train loss 5.482, Val loss 5.576
# Ep 1 (Step 000100): Train loss 5.324, Val loss 5.534
# Ep 1 (Step 000105): Train loss 5.508, Val loss 5.509
# Ep 1 (Step 000110): Train loss 5.308, Val loss 5.478
# Ep 1 (Step 000115): Train loss 5.396, Val loss 5.439
# Ep 1 (Step 000120): Train loss 5.238, Val loss 5.404
# Ep 1 (Step 000125): Train loss 5.303, Val loss 5.385
# Ep 1 (Step 000130): Train loss 5.395, Val loss 5.355
# Ep 1 (Step 000135): Train loss 5.439, Val loss 5.310
# Ep 1 (Step 000140): Train loss 5.109, Val loss 5.298
# Ep 1 (Step 000145): Train loss 5.201, Val loss 5.278
# Ep 2 (Step 002065): Train loss 3.435, Val loss 3.992
# Ep 2 (Step 002070): Train loss 3.509, Val loss 4.000
# Ep 2 (Step 002075): Train loss 3.582, Val loss 4.010
# Ep 2 (Step 002080): Train loss 3.585, Val loss 4.005
# Ep 2 (Step 002085): Train loss 3.501, Val loss 3.990
# Ep 2 (Step 002090): Train loss 3.590, Val loss 3.992
# Ep 2 (Step 002095): Train loss 3.601, Val loss 3.996
# Ep 2 (Step 002100): Train loss 3.359, Val loss 3.993
# Ep 2 (Step 002105): Train loss 3.487, Val loss 3.993
# Ep 2 (Step 002110): Train loss 3.541, Val loss 4.001
# Ep 2 (Step 002115): Train loss 3.423, Val loss 4.004
# Ep 2 (Step 002120): Train loss 3.263, Val loss 4.009
# Ep 2 (Step 002125): Train loss 3.536, Val loss 4.002
# Ep 2 (Step 002130): Train loss 3.308, Val loss 4.008
# Ep 2 (Step 002135): Train loss 3.513, Val loss 3.997
# Ep 2 (Step 002140): Train loss 3.633, Val loss 3.991
# Ep 2 (Step 002145): Train loss 3.527, Val loss 3.991
# Ep 2 (Step 002150): Train loss 3.438, Val loss 3.999
# Ep 2 (Step 002155): Train loss 3.425, Val loss 3.995
# Ep 2 (Step 002160): Train loss 3.599, Val loss 4.007
# Ep 2 (Step 002165): Train loss 3.561, Val loss 4.031
# Ep 2 (Step 002170): Train loss 3.498, Val loss 4.028
# Ep 2 (Step 002175): Train loss 3.748, Val loss 4.017
# Ep 2 (Step 002180): Train loss 3.387, Val loss 4.015
# Ep 2 (Step 002185): Train loss 3.595, Val loss 4.013
# Ep 2 (Step 002190): Train loss 3.479, Val loss 4.003
# Ep 2 (Step 002195): Train loss 3.502, Val loss 3.983
# Ep 2 (Step 002200): Train loss 3.347, Val loss 3.971
# Ep 2 (Step 002205): Train loss 3.427, Val loss 3.978
# Ep 2 (Step 002210): Train loss 3.454, Val loss 3.967
# Ep 2 (Step 002215): Train loss 3.551, Val loss 3.964
# Ep 2 (Step 002220): Train loss 3.355, Val loss 3.967
# Ep 2 (Step 002225): Train loss 3.459, Val loss 3.979
# Ep 2 (Step 002230): Train loss 3.636, Val loss 3.996
# Ep 2 (Step 002235): Train loss 3.447, Val loss 3.994
# Ep 2 (Step 002240): Train loss 3.362, Val loss 3.982
# Ep 2 (Step 002245): Train loss 3.347, Val loss 3.996
# Ep 2 (Step 002250): Train loss 3.416, Val loss 3.973
# Ep 2 (Step 002255): Train loss 3.470, Val loss 3.961
# Ep 2 (Step 002260): Train loss 3.674, Val loss 3.976
# Ep 2 (Step 002265): Train loss 3.426, Val loss 3.980
# Ep 2 (Step 002270): Train loss 3.590, Val loss 3.983
# Ep 2 (Step 002275): Train loss 3.354, Val loss 3.981
# Ep 2 (Step 002280): Train loss 3.456, Val loss 3.969
# Ep 2 (Step 002285): Train loss 3.286, Val loss 3.966
# Ep 2 (Step 002290): Train loss 3.472, Val loss 3.971
# Ep 2 (Step 002295): Train loss 3.385, Val loss 3.955
# Ep 2 (Step 002300): Train loss 3.273, Val loss 3.952
# Ep 2 (Step 002305): Train loss 3.413, Val loss 3.953
# Ep 2 (Step 002310): Train loss 3.381, Val loss 3.955
# Ep 2 (Step 002315): Train loss 3.120, Val loss 3.949
# Ep 2 (Step 002320): Train loss 3.368, Val loss 3.936
# Ep 2 (Step 002325): Train loss 3.454, Val loss 3.946
# Ep 2 (Step 002330): Train loss 3.496, Val loss 3.944
# Ep 2 (Step 002335): Train loss 3.540, Val loss 3.952
# Ep 2 (Step 002340): Train loss 3.343, Val loss 3.956
# Ep 2 (Step 002345): Train loss 3.447, Val loss 3.952
# Ep 2 (Step 002350): Train loss 3.404, Val loss 3.945
# Ep 2 (Step 002355): Train loss 3.379, Val loss 3.963
# Ep 2 (Step 002360): Train loss 3.572, Val loss 3.959
# Ep 2 (Step 002365): Train loss 3.331, Val loss 3.949
# Ep 2 (Step 002370): Train loss 3.294, Val loss 3.952
# Ep 2 (Step 002375): Train loss 3.621, Val loss 3.959
# Ep 2 (Step 002380): Train loss 3.394, Val loss 3.961
# Ep 2 (Step 002385): Train loss 3.364, Val loss 3.950
# Ep 2 (Step 002390): Train loss 3.400, Val loss 3.936
# Ep 2 (Step 002395): Train loss 3.457, Val loss 3.938
# Ep 2 (Step 002400): Train loss 3.326, Val loss 3.939
# Ep 2 (Step 002405): Train loss 3.375, Val loss 3.936
# Ep 2 (Step 002410): Train loss 3.193, Val loss 3.935
# Ep 2 (Step 002415): Train loss 3.449, Val loss 3.935
# Ep 2 (Step 002420): Train loss 3.432, Val loss 3.939
# Ep 2 (Step 002425): Train loss 3.431, Val loss 3.944
# Ep 2 (Step 002430): Train loss 3.471, Val loss 3.934
# Ep 2 (Step 002435): Train loss 3.423, Val loss 3.939
# Ep 2 (Step 002440): Train loss 3.439, Val loss 3.931
# Ep 2 (Step 002445): Train loss 3.385, Val loss 3.931
# Ep 2 (Step 002450): Train loss 3.405, Val loss 3.928
# Ep 2 (Step 002455): Train loss 3.219, Val loss 3.926
# Ep 2 (Step 002460): Train loss 3.260, Val loss 3.911
# Ep 2 (Step 002465): Train loss 3.280, Val loss 3.906
# Ep 2 (Step 002470): Train loss 3.410, Val loss 3.909
# Ep 2 (Step 002475): Train loss 3.367, Val loss 3.903
# Ep 2 (Step 002480): Train loss 3.291, Val loss 3.957
# Ep 2 (Step 002485): Train loss 3.382, Val loss 3.906
# Ep 2 (Step 002490): Train loss 3.507, Val loss 3.914
# Ep 2 (Step 002495): Train loss 3.191, Val loss 3.922
# Ep 2 (Step 002500): Train loss 3.487, Val loss 3.924
# Ep 2 (Step 002505): Train loss 3.352, Val loss 3.917
# Ep 2 (Step 002510): Train loss 3.338, Val loss 3.915
# Ep 2 (Step 002515): Train loss 3.393, Val loss 3.921
# Ep 2 (Step 002520): Train loss 3.279, Val loss 3.896
# Ep 2 (Step 002525): Train loss 3.414, Val loss 3.896
# Ep 2 (Step 002530): Train loss 3.558, Val loss 3.901
# Ep 2 (Step 002535): Train loss 3.203, Val loss 3.891
# Ep 2 (Step 002540): Train loss 3.397, Val loss 3.892
# Ep 2 (Step 002545): Train loss 3.414, Val loss 3.909
# Ep 2 (Step 002550): Train loss 3.160, Val loss 3.908
# Ep 2 (Step 002555): Train loss 3.470, Val loss 3.891
# Ep 2 (Step 002560): Train loss 3.336, Val loss 3.886
# Ep 2 (Step 002565): Train loss 3.242, Val loss 3.900
# Ep 2 (Step 002570): Train loss 3.179, Val loss 3.905
# Ep 2 (Step 002575): Train loss 3.374, Val loss 3.913
# Ep 2 (Step 002580): Train loss 3.222, Val loss 3.916
# Ep 2 (Step 002585): Train loss 3.349, Val loss 3.901
# Ep 2 (Step 002590): Train loss 3.384, Val loss 3.896
# Ep 2 (Step 002595): Train loss 3.106, Val loss 3.897
# Ep 2 (Step 002600): Train loss 3.238, Val loss 3.904
# Ep 2 (Step 002605): Train loss 3.272, Val loss 3.916
# Ep 2 (Step 002610): Train loss 3.429, Val loss 3.904
# Ep 2 (Step 002615): Train loss 3.481, Val loss 3.914
# Ep 2 (Step 002620): Train loss 3.297, Val loss 3.906
# Ep 2 (Step 002625): Train loss 3.152, Val loss 3.888
# Ep 2 (Step 002630): Train loss 3.269, Val loss 3.882
# Ep 2 (Step 002635): Train loss 3.278, Val loss 3.892
# Ep 2 (Step 002640): Train loss 3.389, Val loss 3.897
# Ep 2 (Step 002645): Train loss 3.293, Val loss 3.903
# Ep 2 (Step 002650): Train loss 3.283, Val loss 3.914
# Ep 2 (Step 002655): Train loss 3.239, Val loss 3.909
# Ep 2 (Step 002660): Train loss 3.157, Val loss 3.899
# Ep 2 (Step 002665): Train loss 3.281, Val loss 3.902
# Ep 2 (Step 002670): Train loss 3.358, Val loss 3.897
# Ep 2 (Step 002675): Train loss 3.140, Val loss 3.889
# Ep 2 (Step 002680): Train loss 3.350, Val loss 3.881
# Every effort moves you want to be careful. I'm sorry, I love you. I love you, I love you. I love you. I love you." The little girl smiled and said, "I love you, I love you, I love you,
# Ep 3 (Step 002685): Train loss 3.369, Val loss 3.883
# Ep 3 (Step 002690): Train loss 3.313, Val loss 3.873
# Ep 3 (Step 002695): Train loss 3.225, Val loss 3.867
# Ep 3 (Step 002700): Train loss 3.329, Val loss 3.861
# Ep 3 (Step 002705): Train loss 3.139, Val loss 3.845
# Ep 3 (Step 002710): Train loss 3.288, Val loss 3.844
# Ep 3 (Step 002715): Train loss 3.250, Val loss 3.883
# Ep 3 (Step 002720): Train loss 3.368, Val loss 3.904
# Ep 3 (Step 002725): Train loss 3.257, Val loss 3.877
# Ep 3 (Step 002730): Train loss 3.126, Val loss 3.865
# Ep 3 (Step 002735): Train loss 3.197, Val loss 3.859
# Ep 3 (Step 002740): Train loss 3.310, Val loss 3.867
# Ep 3 (Step 002745): Train loss 3.268, Val loss 3.866
# Ep 3 (Step 002750): Train loss 3.370, Val loss 3.851
# Ep 3 (Step 002755): Train loss 3.175, Val loss 3.835
# Ep 3 (Step 002760): Train loss 3.262, Val loss 3.840
# Ep 3 (Step 002765): Train loss 3.456, Val loss 3.868
# Ep 3 (Step 002770): Train loss 3.239, Val loss 3.844
# Ep 3 (Step 002775): Train loss 3.145, Val loss 3.851
# Ep 3 (Step 002780): Train loss 3.282, Val loss 3.851
# Ep 3 (Step 002785): Train loss 3.174, Val loss 3.860
# Ep 3 (Step 002790): Train loss 3.399, Val loss 3.846
# Ep 3 (Step 002795): Train loss 3.073, Val loss 3.850
# Ep 3 (Step 002800): Train loss 3.259, Val loss 3.838
# Ep 3 (Step 002805): Train loss 3.250, Val loss 3.835
# Ep 3 (Step 002810): Train loss 3.439, Val loss 3.851
# Ep 3 (Step 002815): Train loss 3.157, Val loss 3.857
# Ep 3 (Step 002820): Train loss 3.264, Val loss 3.855
# Ep 3 (Step 002825): Train loss 3.047, Val loss 3.862
# Ep 3 (Step 002830): Train loss 3.085, Val loss 3.881
# Ep 3 (Step 002835): Train loss 3.272, Val loss 3.910
# Ep 3 (Step 002840): Train loss 3.056, Val loss 3.900
# Ep 3 (Step 002845): Train loss 3.100, Val loss 3.865
# Ep 3 (Step 002850): Train loss 3.416, Val loss 3.865
# Ep 3 (Step 002855): Train loss 3.292, Val loss 3.847
# Ep 3 (Step 002860): Train loss 3.224, Val loss 3.850
# Ep 3 (Step 002865): Train loss 3.314, Val loss 3.871
# Ep 3 (Step 002870): Train loss 3.366, Val loss 3.852
# Ep 3 (Step 002875): Train loss 3.337, Val loss 3.852
# Ep 3 (Step 002880): Train loss 3.188, Val loss 3.850
# Ep 3 (Step 002885): Train loss 3.159, Val loss 3.848
# Ep 3 (Step 002890): Train loss 3.432, Val loss 3.878
# Ep 3 (Step 002895): Train loss 3.234, Val loss 3.859
# Ep 3 (Step 002900): Train loss 3.047, Val loss 3.847
# Ep 3 (Step 002905): Train loss 3.201, Val loss 3.849
# Ep 3 (Step 002910): Train loss 3.226, Val loss 3.878
# Ep 3 (Step 002915): Train loss 3.292, Val loss 3.863
# Ep 3 (Step 002920): Train loss 3.335, Val loss 3.860
# Ep 3 (Step 002925): Train loss 3.286, Val loss 3.872
# Ep 3 (Step 002930): Train loss 3.392, Val loss 3.860
# Ep 3 (Step 002935): Train loss 3.040, Val loss 3.848
# Ep 3 (Step 002940): Train loss 3.332, Val loss 3.863
# Ep 3 (Step 002945): Train loss 3.332, Val loss 3.893
# Ep 3 (Step 002950): Train loss 3.243, Val loss 3.877
# Ep 3 (Step 002955): Train loss 3.457, Val loss 3.869
# Ep 3 (Step 002960): Train loss 3.146, Val loss 3.859
# Ep 3 (Step 002965): Train loss 3.417, Val loss 3.860
# Ep 3 (Step 002970): Train loss 3.175, Val loss 3.857
# Ep 3 (Step 002975): Train loss 3.141, Val loss 3.853
# Ep 3 (Step 002980): Train loss 3.246, Val loss 3.867
# Ep 3 (Step 002985): Train loss 3.249, Val loss 3.865
# Ep 3 (Step 002990): Train loss 3.164, Val loss 3.865
# Ep 3 (Step 002995): Train loss 3.162, Val loss 3.862
# Ep 3 (Step 003000): Train loss 3.233, Val loss 3.844
# Ep 3 (Step 003005): Train loss 3.212, Val loss 3.849
# Ep 3 (Step 003010): Train loss 3.128, Val loss 3.887
# Ep 3 (Step 003015): Train loss 3.338, Val loss 3.880
# Ep 3 (Step 003020): Train loss 3.239, Val loss 3.872
# Ep 3 (Step 003025): Train loss 3.185, Val loss 3.882
# Ep 3 (Step 003030): Train loss 3.211, Val loss 3.892
# Ep 3 (Step 003035): Train loss 3.259, Val loss 3.879
# Ep 3 (Step 003040): Train loss 3.151, Val loss 3.876
# Ep 3 (Step 003045): Train loss 3.283, Val loss 3.877
# Ep 3 (Step 003050): Train loss 3.126, Val loss 3.872
# Ep 3 (Step 003055): Train loss 2.974, Val loss 3.878
# Ep 3 (Step 003060): Train loss 3.124, Val loss 3.877
# Ep 3 (Step 003065): Train loss 3.098, Val loss 3.868
# Ep 3 (Step 003070): Train loss 3.248, Val loss 3.871
# Ep 3 (Step 003075): Train loss 3.157, Val loss 3.882
# Ep 3 (Step 003080): Train loss 3.240, Val loss 3.882
# Ep 3 (Step 003085): Train loss 2.992, Val loss 3.863
# Ep 3 (Step 003090): Train loss 3.365, Val loss 3.855
# Ep 3 (Step 003095): Train loss 3.182, Val loss 3.858
# Ep 3 (Step 003100): Train loss 3.041, Val loss 3.858
# Ep 3 (Step 003105): Train loss 3.145, Val loss 3.851
# Ep 3 (Step 003110): Train loss 3.232, Val loss 3.860
# Ep 3 (Step 003115): Train loss 2.927, Val loss 3.873
# Ep 3 (Step 003120): Train loss 3.200, Val loss 3.851
# Ep 3 (Step 003125): Train loss 3.342, Val loss 3.850
# Ep 3 (Step 003130): Train loss 3.061, Val loss 3.828
# Ep 3 (Step 003135): Train loss 3.153, Val loss 3.824
# Ep 3 (Step 003140): Train loss 3.089, Val loss 3.816
# Ep 3 (Step 003145): Train loss 3.261, Val loss 3.807
# Ep 3 (Step 003150): Train loss 3.172, Val loss 3.802
# Ep 3 (Step 003155): Train loss 3.231, Val loss 3.810
# Ep 3 (Step 003160): Train loss 3.114, Val loss 3.814
# Ep 3 (Step 003165): Train loss 3.179, Val loss 3.803
# Ep 3 (Step 003170): Train loss 3.269, Val loss 3.831
# Ep 3 (Step 003175): Train loss 2.967, Val loss 3.842
# Ep 3 (Step 003180): Train loss 3.064, Val loss 3.849
# Ep 3 (Step 003185): Train loss 3.312, Val loss 3.832
# Ep 3 (Step 003190): Train loss 3.208, Val loss 3.818
# Ep 3 (Step 003195): Train loss 3.039, Val loss 3.826
# Ep 3 (Step 003200): Train loss 3.041, Val loss 3.829
# Ep 3 (Step 003205): Train loss 3.197, Val loss 3.838
# Ep 3 (Step 003210): Train loss 3.082, Val loss 3.838
# Ep 3 (Step 003215): Train loss 3.344, Val loss 3.828
# Ep 3 (Step 003220): Train loss 3.150, Val loss 3.803
# Ep 3 (Step 003225): Train loss 3.073, Val loss 3.806
# Ep 3 (Step 003230): Train loss 3.033, Val loss 3.804
# Ep 3 (Step 003235): Train loss 3.145, Val loss 3.821
# Ep 3 (Step 003240): Train loss 3.029, Val loss 3.852
# Ep 3 (Step 003245): Train loss 3.141, Val loss 3.859
# Ep 3 (Step 003250): Train loss 3.189, Val loss 3.848
# Ep 3 (Step 003255): Train loss 2.955, Val loss 3.839
# Ep 3 (Step 003260): Train loss 3.156, Val loss 3.832
# Ep 3 (Step 003265): Train loss 3.208, Val loss 3.833
# Ep 3 (Step 003270): Train loss 3.110, Val loss 3.830
# Ep 3 (Step 003275): Train loss 3.076, Val loss 3.842
# Ep 3 (Step 003280): Train loss 3.051, Val loss 3.820
# Ep 3 (Step 003285): Train loss 3.163, Val loss 3.824
# Ep 3 (Step 003290): Train loss 3.147, Val loss 3.845
# Ep 3 (Step 003295): Train loss 3.210, Val loss 3.819
# Ep 3 (Step 003300): Train loss 3.010, Val loss 3.812
# Ep 3 (Step 003305): Train loss 3.111, Val loss 3.812
# Ep 3 (Step 003310): Train loss 3.218, Val loss 3.812
# Ep 3 (Step 003315): Train loss 3.039, Val loss 3.803
# Ep 3 (Step 003320): Train loss 3.100, Val loss 3.789
# Ep 3 (Step 003325): Train loss 3.138, Val loss 3.781
# Ep 3 (Step 003330): Train loss 2.910, Val loss 3.799
# Ep 3 (Step 003335): Train loss 2.932, Val loss 3.800
# Ep 3 (Step 003340): Train loss 3.052, Val loss 3.791
# Ep 3 (Step 003345): Train loss 3.158, Val loss 3.792
# Ep 3 (Step 003350): Train loss 2.888, Val loss 3.792
# Ep 3 (Step 003355): Train loss 3.205, Val loss 3.797
# Ep 3 (Step 003360): Train loss 3.101, Val loss 3.815
# Ep 3 (Step 003365): Train loss 3.287, Val loss 3.796
# Ep 3 (Step 003370): Train loss 3.196, Val loss 3.782
# Ep 3 (Step 003375): Train loss 3.079, Val loss 3.788
# Ep 3 (Step 003380): Train loss 3.171, Val loss 3.804
# Ep 3 (Step 003385): Train loss 3.006, Val loss 3.795
# Ep 3 (Step 003390): Train loss 3.180, Val loss 3.798
# Ep 3 (Step 003395): Train loss 3.052, Val loss 3.806
# Ep 3 (Step 003400): Train loss 3.030, Val loss 3.791
# Ep 3 (Step 003405): Train loss 3.177, Val loss 3.808
# Ep 3 (Step 003410): Train loss 3.039, Val loss 3.794
# Ep 3 (Step 003415): Train loss 3.104, Val loss 3.800
# Ep 3 (Step 003420): Train loss 2.888, Val loss 3.801
# Ep 3 (Step 003425): Train loss 3.108, Val loss 3.793
# Ep 3 (Step 003430): Train loss 3.144, Val loss 3.788
# Ep 3 (Step 003435): Train loss 3.109, Val loss 3.794
# Ep 3 (Step 003440): Train loss 3.197, Val loss 3.788
# Ep 3 (Step 003445): Train loss 3.213, Val loss 3.786
# Ep 3 (Step 003450): Train loss 3.050, Val loss 3.778
# Ep 3 (Step 003455): Train loss 3.221, Val loss 3.777
# Ep 3 (Step 003460): Train loss 3.199, Val loss 3.795
# Ep 3 (Step 003465): Train loss 3.025, Val loss 3.802
# Ep 3 (Step 003470): Train loss 3.195, Val loss 3.785
# Ep 3 (Step 003475): Train loss 3.150, Val loss 3.793
# Ep 3 (Step 003480): Train loss 3.118, Val loss 3.793
# Ep 3 (Step 003485): Train loss 3.329, Val loss 3.781
# Ep 3 (Step 003490): Train loss 3.173, Val loss 3.789
# Ep 3 (Step 003495): Train loss 2.935, Val loss 3.786
# Ep 3 (Step 003500): Train loss 3.012, Val loss 3.785
# Ep 3 (Step 003505): Train loss 3.013, Val loss 3.778
# Ep 3 (Step 003510): Train loss 3.081, Val loss 3.771
# Ep 3 (Step 003515): Train loss 3.057, Val loss 3.781
# Ep 3 (Step 003520): Train loss 2.909, Val loss 3.779
# Ep 3 (Step 003525): Train loss 2.954, Val loss 3.778
# Ep 3 (Step 003530): Train loss 2.937, Val loss 3.766
# Ep 3 (Step 003535): Train loss 3.177, Val loss 3.768
# Ep 3 (Step 003540): Train loss 2.994, Val loss 3.770
# Ep 3 (Step 003545): Train loss 3.125, Val loss 3.765
# Ep 3 (Step 003550): Train loss 3.171, Val loss 3.760
# Ep 3 (Step 003555): Train loss 3.089, Val loss 3.761
# Ep 3 (Step 003560): Train loss 3.058, Val loss 3.791
# Ep 3 (Step 003565): Train loss 3.102, Val loss 3.774
# Ep 3 (Step 003570): Train loss 2.753, Val loss 3.771
# Ep 3 (Step 003575): Train loss 3.002, Val loss 3.770
# Ep 3 (Step 003580): Train loss 3.006, Val loss 3.769
# Ep 3 (Step 003585): Train loss 3.060, Val loss 3.777
# Ep 3 (Step 003590): Train loss 3.173, Val loss 3.793
# Ep 3 (Step 003595): Train loss 2.978, Val loss 3.793
# Ep 3 (Step 003600): Train loss 2.969, Val loss 3.780
# Ep 3 (Step 003605): Train loss 3.136, Val loss 3.781
# Ep 3 (Step 003610): Train loss 3.085, Val loss 3.768
# Ep 3 (Step 003615): Train loss 3.099, Val loss 3.783
# Ep 3 (Step 003620): Train loss 3.000, Val loss 3.781
# Ep 3 (Step 003625): Train loss 3.105, Val loss 3.783
# Ep 3 (Step 003630): Train loss 2.846, Val loss 3.770
# Ep 3 (Step 003635): Train loss 3.126, Val loss 3.772
# Ep 3 (Step 003640): Train loss 3.209, Val loss 3.790
# Ep 3 (Step 003645): Train loss 3.143, Val loss 3.797
# Ep 3 (Step 003650): Train loss 3.087, Val loss 3.767
# Ep 3 (Step 003655): Train loss 3.142, Val loss 3.750
# Ep 3 (Step 003660): Train loss 2.822, Val loss 3.726
# Ep 3 (Step 003665): Train loss 3.278, Val loss 3.738
# Ep 3 (Step 003670): Train loss 2.903, Val loss 3.744
# Ep 3 (Step 003675): Train loss 2.863, Val loss 3.733
# Ep 3 (Step 003680): Train loss 3.224, Val loss 3.743
# Ep 3 (Step 003685): Train loss 3.181, Val loss 3.733
# Ep 3 (Step 003690): Train loss 3.232, Val loss 3.740
# Ep 3 (Step 003695): Train loss 3.048, Val loss 3.748
# Ep 3 (Step 003700): Train loss 3.069, Val loss 3.747
# Ep 3 (Step 003705): Train loss 3.074, Val loss 3.758
# Ep 3 (Step 003710): Train loss 3.054, Val loss 3.731
# Ep 3 (Step 003715): Train loss 3.039, Val loss 3.716
# Ep 3 (Step 003720): Train loss 3.183, Val loss 3.731
# Ep 3 (Step 003725): Train loss 3.059, Val loss 3.744
# Ep 3 (Step 003730): Train loss 2.927, Val loss 3.719
# Ep 3 (Step 003735): Train loss 3.074, Val loss 3.713
# Ep 3 (Step 003740): Train loss 2.863, Val loss 3.735
# Ep 3 (Step 003745): Train loss 2.796, Val loss 3.738
# Ep 3 (Step 003750): Train loss 2.874, Val loss 3.748
# Ep 3 (Step 003755): Train loss 2.845, Val loss 3.737
# Ep 3 (Step 003760): Train loss 3.308, Val loss 3.738
# Ep 3 (Step 003765): Train loss 2.934, Val loss 3.739
# Ep 3 (Step 003770): Train loss 2.853, Val loss 3.719
# Ep 3 (Step 003775): Train loss 2.966, Val loss 3.719
# Ep 3 (Step 003780): Train loss 3.066, Val loss 3.740
# Ep 3 (Step 003785): Train loss 3.103, Val loss 3.735
# Ep 3 (Step 003790): Train loss 3.067, Val loss 3.728
# Ep 3 (Step 003795): Train loss 2.934, Val loss 3.735
# Ep 3 (Step 003800): Train loss 2.929, Val loss 3.731
# Ep 3 (Step 003805): Train loss 3.076, Val loss 3.746
# Ep 3 (Step 003810): Train loss 2.999, Val loss 3.745
# Ep 3 (Step 003815): Train loss 3.066, Val loss 3.746
# Ep 3 (Step 003820): Train loss 2.933, Val loss 3.732
# Ep 3 (Step 003825): Train loss 3.203, Val loss 3.737
# Ep 3 (Step 003830): Train loss 3.213, Val loss 3.735
# Ep 3 (Step 003835): Train loss 2.939, Val loss 3.724
# Ep 3 (Step 003840): Train loss 2.951, Val loss 3.714
# Ep 3 (Step 003845): Train loss 3.088, Val loss 3.715
# Ep 3 (Step 003850): Train loss 3.053, Val loss 3.724
# Ep 3 (Step 003855): Train loss 3.047, Val loss 3.718
# Ep 3 (Step 003860): Train loss 3.119, Val loss 3.717
# Ep 3 (Step 003865): Train loss 2.954, Val loss 3.718
# Ep 3 (Step 003870): Train loss 2.907, Val loss 3.716
# Ep 3 (Step 003875): Train loss 3.179, Val loss 3.721
# Ep 3 (Step 003880): Train loss 3.054, Val loss 3.728
# Ep 3 (Step 003885): Train loss 2.973, Val loss 3.725
# Ep 3 (Step 003890): Train loss 2.883, Val loss 3.718
# Ep 3 (Step 003895): Train loss 2.823, Val loss 3.715
# Ep 3 (Step 003900): Train loss 3.092, Val loss 3.728
# Ep 3 (Step 003905): Train loss 2.992, Val loss 3.709
# Ep 3 (Step 003910): Train loss 2.791, Val loss 3.701
# Ep 3 (Step 003915): Train loss 2.909, Val loss 3.705
# Ep 3 (Step 003920): Train loss 3.004, Val loss 3.700
# Ep 3 (Step 003925): Train loss 2.919, Val loss 3.684
# Ep 3 (Step 003930): Train loss 3.070, Val loss 3.693
# Ep 3 (Step 003935): Train loss 2.860, Val loss 3.687
# Ep 3 (Step 003940): Train loss 2.903, Val loss 3.693
# Ep 3 (Step 003945): Train loss 2.981, Val loss 3.697
# Ep 3 (Step 003950): Train loss 3.078, Val loss 3.694
# Ep 3 (Step 003955): Train loss 2.973, Val loss 3.704
# Ep 3 (Step 003960): Train loss 2.994, Val loss 3.701
# Ep 3 (Step 003965): Train loss 2.948, Val loss 3.687
# Ep 3 (Step 003970): Train loss 2.893, Val loss 3.685
# Ep 3 (Step 003975): Train loss 3.073, Val loss 3.692
# Ep 3 (Step 003980): Train loss 2.990, Val loss 3.709
# Ep 3 (Step 003985): Train loss 3.000, Val loss 3.705
# Ep 3 (Step 003990): Train loss 2.834, Val loss 3.705
# Ep 3 (Step 003995): Train loss 2.904, Val loss 3.703
# Ep 3 (Step 004000): Train loss 2.831, Val loss 3.699
# Ep 3 (Step 004005): Train loss 3.016, Val loss 3.714
# Ep 3 (Step 004010): Train loss 2.892, Val loss 3.706
# Ep 3 (Step 004015): Train loss 3.027, Val loss 3.707
# Ep 3 (Step 004020): Train loss 2.815, Val loss 3.704
# Ep 3 (Step 004025): Train loss 2.855, Val loss 3.713
# Every effort moves you have to be careful and share the best of the best things. <|endoftext|> Once upon a time, there was a little girl named Lily. She loved to play with her toys. One day, she went to the park. She saw a big
# Ep 4 (Step 004030): Train loss 3.058, Val loss 3.710
# Ep 4 (Step 004035): Train loss 2.917, Val loss 3.709
# Ep 4 (Step 004040): Train loss 2.876, Val loss 3.726
# Ep 4 (Step 004045): Train loss 2.954, Val loss 3.707
# Ep 4 (Step 004050): Train loss 2.924, Val loss 3.690
# Ep 4 (Step 004055): Train loss 2.994, Val loss 3.696
# Ep 4 (Step 004060): Train loss 2.862, Val loss 3.687
# Ep 4 (Step 004065): Train loss 2.946, Val loss 3.675
# Ep 4 (Step 004070): Train loss 2.657, Val loss 3.693
# Ep 4 (Step 004075): Train loss 2.892, Val loss 3.695
# Ep 4 (Step 004080): Train loss 2.899, Val loss 3.697
# Ep 4 (Step 004085): Train loss 3.021, Val loss 3.688
# Ep 4 (Step 004090): Train loss 3.014, Val loss 3.680
# Ep 4 (Step 004095): Train loss 3.019, Val loss 3.688
# Ep 4 (Step 004100): Train loss 3.040, Val loss 3.693
# Ep 4 (Step 004105): Train loss 2.832, Val loss 3.689
# Ep 4 (Step 004110): Train loss 2.777, Val loss 3.692
# Ep 4 (Step 004115): Train loss 3.048, Val loss 3.694
# Ep 4 (Step 004120): Train loss 2.780, Val loss 3.700
# Ep 4 (Step 004125): Train loss 2.979, Val loss 3.713
# Ep 4 (Step 004130): Train loss 2.950, Val loss 3.706
# Ep 4 (Step 004135): Train loss 2.999, Val loss 3.708
# Ep 4 (Step 004140): Train loss 2.922, Val loss 3.693
# Ep 4 (Step 004145): Train loss 3.104, Val loss 3.672
# Ep 4 (Step 004150): Train loss 2.787, Val loss 3.695
# Ep 4 (Step 004155): Train loss 2.829, Val loss 3.678
# Ep 4 (Step 004160): Train loss 3.041, Val loss 3.670
# Ep 4 (Step 004165): Train loss 2.881, Val loss 3.665
# Ep 4 (Step 004170): Train loss 3.022, Val loss 3.681
# Ep 4 (Step 004175): Train loss 2.903, Val loss 3.691
# Ep 4 (Step 004180): Train loss 2.923, Val loss 3.691
# Ep 4 (Step 004185): Train loss 3.039, Val loss 3.681
# Ep 4 (Step 004190): Train loss 2.891, Val loss 3.682
# Ep 4 (Step 004195): Train loss 2.973, Val loss 3.690
# Ep 4 (Step 004200): Train loss 3.001, Val loss 3.688
# Ep 4 (Step 004205): Train loss 2.954, Val loss 3.678
# Ep 13 (Step 017430): Train loss 1.267, Val loss 3.706
# Ep 13 (Step 017435): Train loss 1.397, Val loss 3.696
# Ep 13 (Step 017440): Train loss 1.422, Val loss 3.689
# Ep 13 (Step 017445): Train loss 1.242, Val loss 3.711
# Every effort moves you can't do it. It is a good thing to do. Do you want to try it?" Ben nodded. He said, "Yes, I can. I have a stamp. It is a good idea. I like it." Anna
# Training completed in 347.01 minutes.

# %%
def generate(model, idx, max_new_tokens, context_size, temperature=0.0, top_k=None, eos_id=None):

    # For-loop is the same as before: Get logits, and only focus on last time step
    for _ in range(max_new_tokens):
        idx_cond = idx[:, -context_size:]
        with torch.no_grad():
            logits = model(idx_cond)
        logits = logits[:, -1, :]

        # New: Filter logits with top_k sampling
        if top_k is not None:
            # Keep only top_k values
            top_logits, _ = torch.topk(logits, top_k)
            min_val = top_logits[:, -1]
            logits = torch.where(logits < min_val, torch.tensor(float("-inf")).to(logits.device), logits)

        # New: Apply temperature scaling
        if temperature > 0.0:
            logits = logits / temperature

            # New (not in book): numerical stability tip to get equivalent results on mps device
            # subtract rowwise max before softmax
            logits = logits - logits.max(dim=-1, keepdim=True).values
            
            # Apply softmax to get probabilities
            probs = torch.softmax(logits, dim=-1)  # (batch_size, context_len)

            # Sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1)  # (batch_size, 1)

        # Otherwise same as before: get idx of the vocab entry with the highest logits value
        else:
            idx_next = torch.argmax(logits, dim=-1, keepdim=True)  # (batch_size, 1)

        if idx_next == eos_id:  # Stop generating early if end-of-sequence token is encountered and eos_id is specified
            break

        # Same as before: append sampled index to the running sequence
        idx = torch.cat((idx, idx_next), dim=1)  # (batch_size, num_tokens+1)

    return idx

# %%
inference_device = torch.device("cpu")

model.to(inference_device)
model.eval()

torch.manual_seed(123)

token_ids = generate(
    model=model,
    idx=text_to_token_ids("Every effort moves you", tokenizer).to(inference_device),
    max_new_tokens=15,
    context_size=GPT_CONFIG_124M["context_length"],
    top_k=25,
    temperature=1.5
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  Every effort moves you can look at the new words." Lily felt happy that she could support her

# %%
torch.save({
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    }, 
    os.path.join(parent_dir, "model_and_optimizer_small.pth")
)

# %%
file_path = "dataset/sarcasm/sarcastic.txt"
with open(file_path, "r", encoding="utf-8") as file:
    text_data = file.read()


text_data = text_data[:200081]

total_characters = len(text_data)
total_tokens = len(tokenizer.encode(text_data, allowed_special={'<|endoftext|>'}))

print("Characters:", total_characters)
print("Tokens:", total_tokens)
# Out:
# Characters: 200081
# Tokens: 48698

# %%
# Train/validation ratio
train_ratio = 0.90
split_idx = int(train_ratio * len(text_data))
train_data = text_data[:split_idx]
val_data = text_data[split_idx:]


torch.manual_seed(123)

train_loader = create_dataloader_v1(
    train_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=True,
    shuffle=True,
    num_workers=0
)

val_loader = create_dataloader_v1(
    val_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=False,
    shuffle=False,
    num_workers=0
)

# %%
# checkpoint = torch.load("model_and_optimizer_small.pth", weights_only=True)

# model = GPTModel(GPT_CONFIG_124M)
# model.load_state_dict(checkpoint["model_state_dict"])

# optimizer = torch.optim.AdamW(model.parameters(), lr=0.0005, weight_decay=0.1)
# optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
# model.train();

# %%
import time
start_time = time.time()

torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)
model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0004, weight_decay=0.1)

num_epochs = 15
train_losses, val_losses, tokens_seen = train_model_simple(
    model, train_loader, val_loader, optimizer, device,
    num_epochs=num_epochs, eval_freq=5, eval_iter=5,
    start_context="Every effort moves you", tokenizer=tokenizer
)

end_time = time.time()
execution_time_minutes = (end_time - start_time) / 60
print(f"Training completed in {execution_time_minutes:.2f} minutes.")
# Out:
# Ep 1 (Step 000000): Train loss 10.743, Val loss 10.753
# Ep 1 (Step 000005): Train loss 9.850, Val loss 9.940
# Ep 1 (Step 000010): Train loss 9.355, Val loss 9.457
# Ep 1 (Step 000015): Train loss 8.866, Val loss 8.957
# Ep 1 (Step 000020): Train loss 8.437, Val loss 8.476
# Ep 1 (Step 000025): Train loss 7.872, Val loss 8.069
# Ep 1 (Step 000030): Train loss 7.636, Val loss 7.762
# Ep 1 (Step 000035): Train loss 7.268, Val loss 7.559
# Ep 1 (Step 000040): Train loss 6.989, Val loss 7.431
# Ep 1 (Step 000045): Train loss 7.121, Val loss 7.351
# Ep 1 (Step 000050): Train loss 7.147, Val loss 7.305
# Ep 1 (Step 000055): Train loss 6.907, Val loss 7.266
# Ep 1 (Step 000060): Train loss 6.862, Val loss 7.237
# Ep 1 (Step 000065): Train loss 6.869, Val loss 7.217
# Ep 1 (Step 000070): Train loss 7.028, Val loss 7.189
# Ep 1 (Step 000075): Train loss 6.799, Val loss 7.174
# Ep 1 (Step 000080): Train loss 6.939, Val loss 7.142
# Every effort moves you. I, the the the, the the, the, the the, the the the, the the the the the, the the the, the, the, the, the the the, the the the, the, the, the,
# Ep 2 (Step 000085): Train loss 6.796, Val loss 7.127
# Ep 2 (Step 000090): Train loss 6.684, Val loss 7.125
# Ep 2 (Step 000095): Train loss 6.648, Val loss 7.080
# Ep 2 (Step 000100): Train loss 6.683, Val loss 7.093
# Ep 2 (Step 000105): Train loss 6.524, Val loss 7.056
# Ep 2 (Step 000110): Train loss 6.595, Val loss 7.042
# Ep 2 (Step 000115): Train loss 6.570, Val loss 7.069
# Ep 2 (Step 000120): Train loss 6.539, Val loss 7.016
# Ep 2 (Step 000125): Train loss 6.489, Val loss 6.998
# Ep 2 (Step 000130): Train loss 6.544, Val loss 6.986
# Ep 2 (Step 000135): Train loss 6.298, Val loss 6.964
# Ep 2 (Step 000140): Train loss 6.285, Val loss 6.972
# Ep 2 (Step 000145): Train loss 6.351, Val loss 6.964
# Ep 2 (Step 000150): Train loss 6.310, Val loss 6.947
# Ep 2 (Step 000155): Train loss 6.304, Val loss 6.930
# Ep 2 (Step 000160): Train loss 6.121, Val loss 6.920
# Ep 2 (Step 000165): Train loss 6.067, Val loss 6.912
# Every effort moves you're a the same to be the same to be the same to be the same, it's not the was the game I'm the game I'm the same I'm the game I'm the same the same, you're the
# Ep 3 (Step 000170): Train loss 6.042, Val loss 6.896
# Ep 3 (Step 000175): Train loss 6.158, Val loss 6.884
# Ep 3 (Step 000180): Train loss 6.022, Val loss 6.891
# Ep 3 (Step 000185): Train loss 6.204, Val loss 6.891
# Ep 3 (Step 000190): Train loss 6.100, Val loss 6.895
# Ep 3 (Step 000195): Train loss 6.214, Val loss 6.881
# Ep 3 (Step 000200): Train loss 6.221, Val loss 6.877
# Ep 3 (Step 000205): Train loss 6.062, Val loss 6.861
# Ep 3 (Step 000210): Train loss 6.006, Val loss 6.855
# Ep 3 (Step 000215): Train loss 5.922, Val loss 6.856
# Ep 3 (Step 000220): Train loss 5.835, Val loss 6.850
# Ep 3 (Step 000225): Train loss 5.888, Val loss 6.842
# Ep 3 (Step 000230): Train loss 5.905, Val loss 6.841
# Ep 3 (Step 000235): Train loss 5.724, Val loss 6.842
# Ep 3 (Step 000240): Train loss 5.790, Val loss 6.829
# Ep 3 (Step 000245): Train loss 5.699, Val loss 6.828
# Ep 3 (Step 000250): Train loss 5.966, Val loss 6.829
# Every effort moves you're a game But the same, you're not, it's a game and you're a great But it's not, you're not, it's not the same, you're not a game But it's not like the same
# Ep 4 (Step 000255): Train loss 5.742, Val loss 6.818
# Ep 4 (Step 000260): Train loss 5.748, Val loss 6.802
# Ep 4 (Step 000265): Train loss 5.715, Val loss 6.797
# Ep 4 (Step 000270): Train loss 5.619, Val loss 6.800
# Ep 4 (Step 000275): Train loss 5.519, Val loss 6.816
# Ep 4 (Step 000280): Train loss 5.578, Val loss 6.813
# Ep 4 (Step 000285): Train loss 5.592, Val loss 6.802
# Ep 4 (Step 000290): Train loss 5.636, Val loss 6.796
# Ep 4 (Step 000295): Train loss 5.642, Val loss 6.789
# Ep 4 (Step 000300): Train loss 5.664, Val loss 6.771
# Ep 4 (Step 000305): Train loss 5.483, Val loss 6.803
# Ep 4 (Step 000310): Train loss 5.454, Val loss 6.778
# Ep 4 (Step 000315): Train loss 5.270, Val loss 6.782
# Ep 4 (Step 000320): Train loss 5.269, Val loss 6.762
# Ep 4 (Step 000325): Train loss 5.450, Val loss 6.761
# Ep 4 (Step 000330): Train loss 5.441, Val loss 6.783
# Ep 4 (Step 000335): Train loss 5.555, Val loss 6.777
# Every effort moves you're a good. I'm sure that the game, it's a great But it's a few I'm sure that's a good? I'm sure that you're a great of the world is a great of the same
# Ep 5 (Step 000340): Train loss 5.375, Val loss 6.786
# Ep 5 (Step 000345): Train loss 5.215, Val loss 6.768
# Ep 5 (Step 000350): Train loss 5.323, Val loss 6.761
# Ep 5 (Step 000355): Train loss 5.267, Val loss 6.758
# Ep 5 (Step 000360): Train loss 5.274, Val loss 6.757
# Ep 5 (Step 000365): Train loss 5.303, Val loss 6.749
# Ep 5 (Step 000370): Train loss 5.247, Val loss 6.781
# Ep 5 (Step 000375): Train loss 5.319, Val loss 6.762
# Ep 5 (Step 000380): Train loss 5.110, Val loss 6.756
# Ep 5 (Step 000385): Train loss 5.000, Val loss 6.758
# Ep 5 (Step 000390): Train loss 5.137, Val loss 6.746
# Ep 5 (Step 000395): Train loss 5.219, Val loss 6.759
# Ep 5 (Step 000400): Train loss 5.074, Val loss 6.768
# Ep 5 (Step 000405): Train loss 4.959, Val loss 6.751
# Ep 5 (Step 000410): Train loss 4.922, Val loss 6.760
# Ep 5 (Step 000415): Train loss 5.072, Val loss 6.731
# Ep 5 (Step 000420): Train loss 4.966, Val loss 6.745
# Every effort moves you're not the same But it's a good and the game and you're not like the same. But it's not like the best, we can't have a good. I'm sure the same and you are all the same of
# Ep 6 (Step 000425): Train loss 4.872, Val loss 6.734
# Ep 6 (Step 000430): Train loss 4.827, Val loss 6.750
# Ep 6 (Step 000435): Train loss 4.856, Val loss 6.747
# Ep 6 (Step 000440): Train loss 4.827, Val loss 6.766
# Ep 6 (Step 000445): Train loss 4.880, Val loss 6.775
# Ep 6 (Step 000450): Train loss 4.566, Val loss 6.794
# Ep 6 (Step 000455): Train loss 4.859, Val loss 6.783
# Ep 6 (Step 000460): Train loss 4.844, Val loss 6.789
# Ep 6 (Step 000465): Train loss 4.817, Val loss 6.788
# Ep 6 (Step 000470): Train loss 4.654, Val loss 6.788
# Ep 6 (Step 000475): Train loss 4.564, Val loss 6.769
# Ep 6 (Step 000480): Train loss 4.559, Val loss 6.766
# Ep 6 (Step 000485): Train loss 4.613, Val loss 6.763
# Ep 6 (Step 000490): Train loss 4.531, Val loss 6.763
# Ep 6 (Step 000495): Train loss 4.469, Val loss 6.773
# Ep 6 (Step 000500): Train loss 4.551, Val loss 6.768
# Ep 6 (Step 000505): Train loss 4.414, Val loss 6.782
# Every effort moves you're not the same You're not the same and you're not the game and you're a good. You're not the same of the game. I'm sure the game. But it's just don't you're a good
# Ep 7 (Step 000510): Train loss 4.446, Val loss 6.766
# Ep 7 (Step 000515): Train loss 4.271, Val loss 6.773
# Ep 7 (Step 000520): Train loss 4.313, Val loss 6.777
# Ep 7 (Step 000525): Train loss 4.408, Val loss 6.793
# Ep 7 (Step 000530): Train loss 4.247, Val loss 6.811
# Ep 7 (Step 000535): Train loss 4.154, Val loss 6.813
# Ep 7 (Step 000540): Train loss 4.344, Val loss 6.826
# Ep 7 (Step 000545): Train loss 4.184, Val loss 6.830
# Ep 7 (Step 000550): Train loss 4.200, Val loss 6.832
# Ep 7 (Step 000555): Train loss 4.165, Val loss 6.827
# Ep 7 (Step 000560): Train loss 3.982, Val loss 6.841
# Ep 7 (Step 000565): Train loss 4.242, Val loss 6.840
# Ep 7 (Step 000570): Train loss 4.057, Val loss 6.838
# Ep 7 (Step 000575): Train loss 3.972, Val loss 6.850
# Ep 7 (Step 000580): Train loss 4.204, Val loss 6.836
# Ep 7 (Step 000585): Train loss 4.042, Val loss 6.840
# Ep 7 (Step 000590): Train loss 3.915, Val loss 6.836
# Every effort moves you're not the same and the game and the game and the game. But but you're not like a game. Yeah, the best and I'm sure it's just don't have a game. But it's not like you're
# Ep 8 (Step 000595): Train loss 3.870, Val loss 6.835
# Ep 8 (Step 000600): Train loss 3.748, Val loss 6.836
# Ep 8 (Step 000605): Train loss 3.885, Val loss 6.849
# Ep 8 (Step 000610): Train loss 3.840, Val loss 6.860
# Ep 8 (Step 000615): Train loss 3.734, Val loss 6.884
# Ep 8 (Step 000620): Train loss 3.679, Val loss 6.883
# Ep 8 (Step 000625): Train loss 3.605, Val loss 6.896
# Ep 8 (Step 000630): Train loss 3.568, Val loss 6.907
# Ep 8 (Step 000635): Train loss 3.548, Val loss 6.924
# Ep 8 (Step 000640): Train loss 3.511, Val loss 6.947
# Ep 8 (Step 000645): Train loss 3.689, Val loss 6.962
# Ep 8 (Step 000650): Train loss 3.541, Val loss 6.948
# Ep 8 (Step 000655): Train loss 3.633, Val loss 6.958
# Ep 8 (Step 000660): Train loss 3.302, Val loss 6.953
# Ep 8 (Step 000665): Train loss 3.405, Val loss 6.961
# Ep 8 (Step 000670): Train loss 3.413, Val loss 6.966
# Ep 8 (Step 000675): Train loss 3.431, Val loss 6.994
# Every effort moves you're a I'm sure will be racist if I think of my son of a lot of the time in the game... I'm sure the game... I'm sure there to put in the game of a lot of the game and make
# Ep 9 (Step 000680): Train loss 3.236, Val loss 6.979
# Ep 9 (Step 000685): Train loss 3.294, Val loss 6.977
# Ep 9 (Step 000690): Train loss 3.303, Val loss 6.989
# Ep 9 (Step 000695): Train loss 2.836, Val loss 7.016
# Ep 9 (Step 000700): Train loss 3.264, Val loss 7.011
# Ep 9 (Step 000705): Train loss 3.058, Val loss 7.024
# Ep 9 (Step 000710): Train loss 3.029, Val loss 7.028
# Ep 9 (Step 000715): Train loss 3.090, Val loss 7.066
# Ep 9 (Step 000720): Train loss 3.129, Val loss 7.072
# Ep 9 (Step 000725): Train loss 2.951, Val loss 7.094
# Ep 9 (Step 000730): Train loss 2.861, Val loss 7.064
# Ep 9 (Step 000735): Train loss 2.700, Val loss 7.058
# Ep 9 (Step 000740): Train loss 2.852, Val loss 7.073
# Ep 9 (Step 000745): Train loss 2.703, Val loss 7.099
# Ep 9 (Step 000750): Train loss 3.061, Val loss 7.117
# Ep 9 (Step 000755): Train loss 3.026, Val loss 7.130
# Ep 9 (Step 000760): Train loss 2.780, Val loss 7.110
# Every effort moves you just a I'm sure, right the next time you're not see that the country. I'm sure is a good to me in the " only one Yeah, and will be racist for the "economic. Because only white people
# Ep 10 (Step 000765): Train loss 2.592, Val loss 7.104
# Ep 10 (Step 000770): Train loss 2.557, Val loss 7.132
# Ep 10 (Step 000775): Train loss 2.421, Val loss 7.150
# Ep 10 (Step 000780): Train loss 2.593, Val loss 7.173
# Ep 10 (Step 000785): Train loss 2.684, Val loss 7.180
# Ep 10 (Step 000790): Train loss 2.331, Val loss 7.181
# Ep 10 (Step 000795): Train loss 2.418, Val loss 7.206
# Ep 10 (Step 000800): Train loss 2.412, Val loss 7.232
# Ep 10 (Step 000805): Train loss 2.358, Val loss 7.247
# Ep 10 (Step 000810): Train loss 2.465, Val loss 7.221
# Ep 10 (Step 000815): Train loss 2.337, Val loss 7.238
# Ep 10 (Step 000820): Train loss 2.308, Val loss 7.265
# Ep 10 (Step 000825): Train loss 2.258, Val loss 7.243
# Ep 10 (Step 000830): Train loss 2.280, Val loss 7.279
# Ep 10 (Step 000835): Train loss 2.397, Val loss 7.288
# Ep 10 (Step 000840): Train loss 2.043, Val loss 7.297
# Ep 10 (Step 000845): Train loss 2.259, Val loss 7.288
# Every effort moves you're not going to do with his rise to fame But, it's ancients extra pack. But but, he's just never was never caught But he's not, right? But how much as a plague. But you
# Ep 11 (Step 000850): Train loss 2.023, Val loss 7.275
# Ep 11 (Step 000855): Train loss 1.917, Val loss 7.318
# Ep 11 (Step 000860): Train loss 2.106, Val loss 7.337
# Ep 11 (Step 000865): Train loss 1.798, Val loss 7.349
# Ep 11 (Step 000870): Train loss 1.947, Val loss 7.338
# Ep 11 (Step 000875): Train loss 1.847, Val loss 7.359
# Ep 11 (Step 000880): Train loss 1.606, Val loss 7.405
# Ep 11 (Step 000885): Train loss 1.818, Val loss 7.419
# Ep 11 (Step 000890): Train loss 1.767, Val loss 7.396
# Ep 11 (Step 000895): Train loss 1.910, Val loss 7.409
# Ep 11 (Step 000900): Train loss 1.581, Val loss 7.454
# Ep 11 (Step 000905): Train loss 1.638, Val loss 7.476
# Ep 11 (Step 000910): Train loss 1.554, Val loss 7.509
# Ep 11 (Step 000915): Train loss 1.824, Val loss 7.498
# Ep 11 (Step 000920): Train loss 1.544, Val loss 7.478
# Ep 11 (Step 000925): Train loss 1.525, Val loss 7.508
# Ep 11 (Step 000930): Train loss 1.579, Val loss 7.506
# Every effort moves you. I like I think it was asking for it Yeah but but he's Australian, it's likely... Also! Yeah but if I can make us on to be racist to RT, *t to do that in a But you
# Ep 12 (Step 000935): Train loss 1.482, Val loss 7.514
# Ep 12 (Step 000940): Train loss 1.555, Val loss 7.525
# Ep 12 (Step 000945): Train loss 1.570, Val loss 7.541
# Ep 12 (Step 000950): Train loss 1.417, Val loss 7.562
# Ep 12 (Step 000955): Train loss 1.445, Val loss 7.556
# Ep 12 (Step 000960): Train loss 1.492, Val loss 7.574
# Ep 12 (Step 000965): Train loss 1.267, Val loss 7.605
# Ep 12 (Step 000970): Train loss 1.294, Val loss 7.640
# Ep 12 (Step 000975): Train loss 1.238, Val loss 7.637
# Ep 12 (Step 000980): Train loss 1.411, Val loss 7.664
# Ep 12 (Step 000985): Train loss 1.249, Val loss 7.663
# Ep 12 (Step 000990): Train loss 1.259, Val loss 7.686
# Ep 12 (Step 000995): Train loss 1.334, Val loss 7.666
# Ep 12 (Step 001000): Train loss 1.201, Val loss 7.682
# Ep 12 (Step 001005): Train loss 1.168, Val loss 7.699
# Ep 12 (Step 001010): Train loss 1.040, Val loss 7.721
# Ep 12 (Step 001015): Train loss 1.201, Val loss 7.716
# Every effort moves you know that the best RB in the game and the game. You can't get a kneeler? Because fuck! But you know how to me at releasing balanced skill of the game. But they're not like them you get
# Ep 13 (Step 001020): Train loss 1.078, Val loss 7.704
# Ep 13 (Step 001025): Train loss 1.140, Val loss 7.753
# Ep 13 (Step 001030): Train loss 1.112, Val loss 7.762
# Ep 13 (Step 001035): Train loss 1.038, Val loss 7.768
# Ep 13 (Step 001040): Train loss 0.955, Val loss 7.804
# Ep 13 (Step 001045): Train loss 0.987, Val loss 7.829
# Ep 13 (Step 001050): Train loss 0.964, Val loss 7.823
# Ep 13 (Step 001055): Train loss 1.088, Val loss 7.804
# Ep 13 (Step 001060): Train loss 1.015, Val loss 7.814
# Ep 13 (Step 001065): Train loss 1.017, Val loss 7.859
# Ep 13 (Step 001070): Train loss 0.925, Val loss 7.898
# Ep 13 (Step 001075): Train loss 0.903, Val loss 7.881
# Ep 13 (Step 001080): Train loss 0.850, Val loss 7.891
# Ep 13 (Step 001085): Train loss 0.775, Val loss 7.902
# Ep 13 (Step 001090): Train loss 0.803, Val loss 7.901
# Ep 13 (Step 001095): Train loss 0.744, Val loss 7.900
# Ep 13 (Step 001100): Train loss 0.943, Val loss 7.914
# Every effort moves you just a I don't know man there was one statue to the virgin Mary with a kneeler infront of it at my church the 10 statues of Jesus might of been there to assassinate Trump. But separating and demonizing people to that
# Ep 14 (Step 001105): Train loss 0.767, Val loss 7.916
# Ep 14 (Step 001110): Train loss 0.729, Val loss 7.945
# Ep 14 (Step 001115): Train loss 0.706, Val loss 7.973
# Ep 14 (Step 001120): Train loss 0.783, Val loss 7.994
# Ep 14 (Step 001125): Train loss 0.717, Val loss 8.004
# Ep 14 (Step 001130): Train loss 0.728, Val loss 8.041
# Ep 14 (Step 001135): Train loss 0.609, Val loss 8.042
# Ep 14 (Step 001140): Train loss 0.692, Val loss 8.059
# Ep 14 (Step 001145): Train loss 0.826, Val loss 8.055
# Ep 14 (Step 001150): Train loss 0.578, Val loss 8.048
# Ep 14 (Step 001155): Train loss 0.653, Val loss 8.066
# Ep 14 (Step 001160): Train loss 0.666, Val loss 8.098
# Ep 14 (Step 001165): Train loss 0.625, Val loss 8.124
# Ep 14 (Step 001170): Train loss 0.509, Val loss 8.132
# Ep 14 (Step 001175): Train loss 0.495, Val loss 8.135
# Ep 14 (Step 001180): Train loss 0.594, Val loss 8.165
# Ep 14 (Step 001185): Train loss 0.571, Val loss 8.130
# Every effort moves you just a I think that I think that I flip past all the transmission locking up would have been the game with his defense and. How about Marcos Rojo? I thought it's great when we should just ignore statistics altogether cause they are
# Ep 15 (Step 001190): Train loss 0.557, Val loss 8.134
# Ep 15 (Step 001195): Train loss 0.529, Val loss 8.183
# Ep 15 (Step 001200): Train loss 0.476, Val loss 8.173
# Ep 15 (Step 001205): Train loss 0.512, Val loss 8.191
# Ep 15 (Step 001210): Train loss 0.438, Val loss 8.206
# Ep 15 (Step 001215): Train loss 0.496, Val loss 8.228
# Ep 15 (Step 001220): Train loss 0.519, Val loss 8.268
# Ep 15 (Step 001225): Train loss 0.418, Val loss 8.269
# Ep 15 (Step 001230): Train loss 0.457, Val loss 8.262
# Ep 15 (Step 001235): Train loss 0.409, Val loss 8.270
# Ep 15 (Step 001240): Train loss 0.431, Val loss 8.293
# Ep 15 (Step 001245): Train loss 0.397, Val loss 8.298
# Ep 15 (Step 001250): Train loss 0.364, Val loss 8.291
# Ep 15 (Step 001255): Train loss 0.339, Val loss 8.284
# Ep 15 (Step 001260): Train loss 0.389, Val loss 8.272
# Ep 15 (Step 001265): Train loss 0.354, Val loss 8.298
# Ep 15 (Step 001270): Train loss 0.393, Val loss 8.319
# Every effort moves you just a book that Did you have/10 in the game I'm sure it's just keep and saviour I thought Mother Nature was in charge of trees. Yeah, because America is thriving on the 22 karma he got a skin
# Training completed in 26.12 minutes.

# %%
inference_device = torch.device("cpu")

model.to(inference_device)
model.eval()

torch.manual_seed(123)

token_ids = generate(
    model=model,
    idx=text_to_token_ids("God is great", tokenizer).to(inference_device),
    max_new_tokens=15,
    context_size=GPT_CONFIG_124M["context_length"],
    top_k=25,
    temperature=1.5
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  God is great.
# Donnie 2 saves, but to be better is "economic anxiety

# %%
# torch.save({
#     "model_state_dict": model.state_dict(),
#     "optimizer_state_dict": optimizer.state_dict(),
#     }, 
#     "model_and_optimizer_small_sarcasm.pth"
# )
